# %%
import pandas as pd

# %%
df_bordeaux=pd.read_csv("listings_bordeaux.csv")

# %%
df_bordeaux
# Out:
#                        id                                      listing_url  \
# 0      579652405189065070  https://www.airbnb.com/rooms/579652405189065070
# 1                49797548            https://www.airbnb.com/rooms/49797548
# 2                  218103              https://www.airbnb.com/rooms/218103
# 3                 1117474             https://www.airbnb.com/rooms/1117474
# 4                 1136724             https://www.airbnb.com/rooms/1136724
# ...                   ...                                              ...
# 10880  591221838086690180  https://www.airbnb.com/rooms/591221838086690180
# 10881            50594474            https://www.airbnb.com/rooms/50594474
# 10882  556379338554707629  https://www.airbnb.com/rooms/556379338554707629
# 10883            16789721            https://www.airbnb.com/rooms/16789721
# 10884  678024184489558143  https://www.airbnb.com/rooms/678024184489558143
#
#             scrape_id last_scraped           source  \
# 0      20220912200234   2022-09-12      city scrape
# 1      20220912200234   2022-09-12      city scrape
# 2      20220912200234   2022-09-13      city scrape
# 3      20220912200234   2022-09-13      city scrape
# 4      20220912200234   2022-09-12      city scrape
# ...               ...          ...              ...
# 10880  20220912200234   2022-09-13  previous scrape
# 10881  20220912200234   2022-09-13      city scrape
# 10882  20220912200234   2022-09-13      city scrape
# 10883  20220912200234   2022-09-13  previous scrape
# 10884  20220912200234   2022-09-13  previous scrape
#
#                                                    name  \
# 0      Appartement cosy dans centre historique de Bourg
# 1        Maison de vacances entre Bordeaux et le Bassin
# 2                    B&B Apart.Suite  / tropical garden
# 3                          INCROYABLE T3 EN HYPERCENTRE
# 4         Spacious house, 4 guests with Garden & Garage
# ...                                                 ...
# 10880  Maison chaleureuse avec piscine près de Bordeaux
# 10881                            Le clos des vignes****
# 10882           escale gourmande au coeur des vignobles
# 10883     Logement aux portes de Bordeaux et de l'océan
# 10884        Jolie maison familiale avec jardin paysagé
#
#                                              description  \
# 0      Dans le centre historique de Bourg, idéalement...
# 1      Villa moderne idéalement située entre Bordeaux...
# 2      <b>The space</b><br />The Bambooyard  : "Le cl...
# 3      <b>The space</b><br />In the heart of the hist...
# 4      BOOK A STREET ART HOUSE! Cozy, colorful and cl...
# ...                                                  ...
# 10880  Bienvenue dans notre maison ! <br />C'est notr...
# 10881  À 20 minutes de Bordeaux et à 3 minutes des so...
# 10882  studio independant comportant:<br /><br /> une...
# 10883  Situé au départ de la route des châteaux, à 10...
# 10884  Notre maison familiale se situe dans un lotiss...
#
#                                    neighborhood_overview  \
# 0      Vous vous situez dans le centre historique de ...
# 1      Ballades à pied ou à vélo dans la foret: 5 vél...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10880  Nous sommes situés à 20 min de la gare de bord...
# 10881                                                NaN
# 10882  quartier calme ambiance vigne et campagne à 2 ...
# 10883                                     Quartier calme
# 10884  Notre maison se trouve dans un petit lotisseme...
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...   15134863  ...
# 1      https://a0.muscache.com/pictures/miso/Hosting-...   83677621  ...
# 2      https://a0.muscache.com/pictures/9ba23c8f-4780...    1127981  ...
# 3      https://a0.muscache.com/pictures/20359851/80f7...    6133211  ...
# 4      https://a0.muscache.com/pictures/b876925a-2b69...    3774373  ...
# ...                                                  ...        ...  ...
# 10880  https://a0.muscache.com/pictures/miso/Hosting-...    5220890  ...
# 10881  https://a0.muscache.com/pictures/miso/Hosting-...  408562043  ...
# 10882  https://a0.muscache.com/pictures/6349e9f7-cdce...   62440676  ...
# 10883  https://a0.muscache.com/pictures/miso/Hosting-...  111565429  ...
# 10884  https://a0.muscache.com/pictures/miso/Hosting-...   23002270  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            5.00                   5.00                4.93
# 1                            5.00                   5.00                5.00
# 2                            4.96                   4.57                4.54
# 3                            4.88                   4.93                4.80
# 4                            4.91                   4.62                4.70
# ...                           ...                    ...                 ...
# 10880                         NaN                    NaN                 NaN
# 10881                        4.95                   4.74                4.83
# 10882                        4.77                   4.73                4.64
# 10883                        5.00                   4.88                4.88
# 10884                         NaN                    NaN                 NaN
#
#              license instant_bookable calculated_host_listings_count  \
# 0                NaN                t                              1
# 1                NaN                f                              1
# 2                NaN                f                              4
# 3      330630009852A                f                              1
# 4      33063003349C9                t                              4
# ...              ...              ...                            ...
# 10880            NaN                t                              1
# 10881            NaN                f                              2
# 10882            NaN                t                              3
# 10883            NaN                t                              1
# 10884            NaN                f                              1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               1
# 2                                               4
# 3                                               1
# 4                                               4
# ...                                           ...
# 10880                                           1
# 10881                                           2
# 10882                                           2
# 10883                                           1
# 10884                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 10880                                            0
# 10881                                            0
# 10882                                            1
# 10883                                            0
# 10884                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              2.74
# 1                                               0              0.21
# 2                                               0              0.44
# 3                                               0              3.31
# 4                                               0              4.36
# ...                                           ...               ...
# 10880                                           0               NaN
# 10881                                           0              5.73
# 10882                                           0              6.11
# 10883                                           0              0.26
# 10884                                           0               NaN
#
# [10885 rows x 75 columns]

# %%
df_bordeaux.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
df_bordeaux_neighbourhood=df_bordeaux[["host_id","number_of_reviews","neighbourhood_cleansed"]].groupby("neighbourhood_cleansed").count()

# %%
df_bordeaux_neighbourhood
# Out:
#                         host_id  number_of_reviews
# neighbourhood_cleansed
# 3M-Bourgailh                 10                 10
# Ambars-et-Lagrave            69                 69
# Ambs                         57                 57
# Arago-La Chataigneraie       58                 58
# Arlac                        98                 98
# ...                         ...                ...
# Sardine                      21                 21
# Talence                     494                494
# Toctoucau                    18                 18
# Verthamon                    26                 26
# Villenave-d'Ornon           320                320
#
# [62 rows x 2 columns]

# %%
df_ansers=df_bordeaux[["host_acceptance_rate","host_response_rate"]].dropna()
for col in df_ansers : 
    df_ansers[col]=df_ansers[col].str.replace('%',' ')

# %%
df_ansers=df_bordeaux[["host_acceptance_rate","host_response_rate"]].dropna()
for col in df_ansers.columns : 
    df_ansers[col]=df_ansers[col].str.replace('%','')
    df_ansers[col]=df_ansers[col].astype('int')
df_ansers.mean()
# Out:
# host_acceptance_rate    83.217050
# host_response_rate      94.098051
# dtype: float64

# %%
df_verefication=df_bordeaux[['host_verifications',"host_id"]]
#df_verefication.reset_index(inplace=True)
def porcentage_ver(df):
    totale_verification=df.shape[0]
    number_phone=df[df['host_verifications'].str.contains('phone')]['host_verifications'].count()
    porcent_phone=(number_phone/totale_verification)*100
    number_email=df[df['host_verifications'].str.contains('email')]['host_verifications'].count()
    porcent_email=(number_email/totale_verification)*100
    number_email_work=df[df['host_verifications'].str.contains('work_email')]['host_verifications'].count()
    porcent_email_work=(number_email_work/totale_verification)*100
    print("le nombre des verifivation par email : ", porcent_email)
    print("le nombre des verifivation par telephone : ", porcent_phone  )
    print("le nombre des verifivation par email professionel : ", porcent_email_work)
    return

# %%
df_bordeaux[['host_verifications',"host_id"]].groupby('host_verifications').count()
# Out:
#                                   host_id
# host_verifications
# ['email', 'phone', 'work_email']      677
# ['email', 'phone']                   9287
# ['email', 'work_email']                 1
# ['email']                              45
# ['phone', 'work_email']                24
# ['phone']                             820
# []                                     31

# %%
porcentage_ver(df_verefication)
# Out:
# le nombre des verifivation par email :  92.18190169958659
# le nombre des verifivation par telephone :  99.29260450160771
# le nombre des verifivation par email professionel :  6.449242076251722

# %%
df_room=df_bordeaux[['room_type','amenities']]
for i in range(df_room.shape[0]):
    A=df_room['amenities'][i]
    A=len(A.split(',')df_room['amenities'][i])
# Out:
# 39

# %%
df_room=df_bordeaux[['room_type','amenities']]
for i in range(df_room.shape[0]):
    A=df_room['amenities'][i]
    A=len(A.split(',')df_room['amenities'][i])l=["hamza","elbrek"]
len(l)
# Out:
# 2

# %%
df_room=df_bordeaux[['room_type','amenities']]
for i in range(df_room.shape[0]):
    A=df_room['amenities'][i]
    df_room['amenities'][i]=len(A.split(','))
df_room_mean=df_room.groupby('room_type').mean()
df_room_std=df_room.groupby('room_type').std()
# Out:
# /tmp/ipykernel_43178/2697224123.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_room['amenities'][i]=len(A.split(','))

# %%
df_room_mean
# Out:
#                  amenities
# room_type
# Entire home/apt  27.603407
# Hotel room       26.177778
# Private room     21.365678
# Shared room      15.411765

# %%
df_room_std
# Out:
#                  amenities
# room_type
# Entire home/apt  14.178751
# Hotel room       14.458858
# Private room     12.438094
# Shared room       7.957415

# %%
df_price=df_bordeaux[['room_type','price']]
df_price['price']=df_price['price'].str.replace('$','')
df_price['price']=df_price['price'].str.replace(',','')
df_price['price']=df_price['price'].astype(float)
df_price
# Out:
# /tmp/ipykernel_43178/828885460.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_price['price']=df_price['price'].str.replace('$','')
# /tmp/ipykernel_43178/828885460.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price['price']=df_price['price'].str.replace('$','')
# /tmp/ipykernel_43178/828885460.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price['price']=df_price['price'].str.replace(',','')
# /tmp/ipykernel_43178/828885460.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_price['price']=df_price['price'].astype(float)
#              room_type  price
# 0      Entire home/apt   60.0
# 1      Entire home/apt  280.0
# 2      Entire home/apt  110.0
# 3      Entire home/apt  120.0
# 4      Entire home/apt  139.0
# ...                ...    ...
# 10880  Entire home/apt  230.0
# 10881  Entire home/apt  107.0
# 10882  Entire home/apt   59.0
# 10883  Entire home/apt   90.0
# 10884  Entire home/apt  135.0
#
# [10885 rows x 2 columns]

# %%
df_price_mean=df_price.groupby('room_type').mean()
df_price_mean
# Out:
#                       price
# room_type
# Entire home/apt  119.815449
# Hotel room       146.311111
# Private room      60.055734
# Shared room       51.500000

# %%
df_price_max=df_price.groupby('room_type').max()
df_price_max
# Out:
#                   price
# room_type
# Entire home/apt  8890.0
# Hotel room        391.0
# Private room     1492.0
# Shared room       275.0

# %%
df_price_min=df_price.groupby('room_type').min()
df_price_min
# Out:
#                  price
# room_type
# Entire home/apt   12.0
# Hotel room         0.0
# Private room      10.0
# Shared room        9.0

# %%
df_price_describe=df_price.groupby('room_type').describe()
df_price_describe
# Out:
#                   price                                                       \
#                   count        mean         std   min     25%    50%     75%
# room_type
# Entire home/apt  8278.0  119.815449  174.163674  12.0   60.00   84.0  130.00
# Hotel room         45.0  146.311111   85.464193   0.0  100.00  131.0  169.00
# Private room     2494.0   60.055734   75.827128  10.0   30.00   40.0   60.00
# Shared room        68.0   51.500000   47.769190   9.0   25.75   42.5   49.25
#
#
#                     max
# room_type
# Entire home/apt  8890.0
# Hotel room        391.0
# Private room     1492.0
# Shared room       275.0

# %%
df_correlation=df_bordeaux[['number_of_reviews','description']]
for i in range(df_correlation.shape[0]):
    if type(df_correlation['description'][i])!=float :
        A=len(df_correlation['description'][i])
        df_correlation['description'][i]=A
df_correlation['description']=df_correlation['description'].astype(float)
# Out:
# /tmp/ipykernel_43178/1997356056.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_correlation['description'][i]=A
# /tmp/ipykernel_43178/1997356056.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_correlation['description']=df_correlation['description'].astype(float)

# %%
df_correlation.corr()
# Out:
#                    number_of_reviews  description
# number_of_reviews           1.000000     0.184217
# description                 0.184217     1.000000

# %%
df_reviews_bordeaux=pd.read_csv('reviews_bordeaux.csv')
df_reviews_bordeaux
# Out:
#                 listing_id        date
# 0                   218103  2011-11-11
# 1                   218103  2012-04-12
# 2                   218103  2012-04-12
# 3                   218103  2012-04-14
# 4                   218103  2012-05-02
# ...                    ...         ...
# 306351  676160559071430643  2022-08-21
# 306352  676172890468973421  2022-08-09
# 306353  676172890468973421  2022-08-14
# 306354  676199336545361956  2022-08-14
# 306355  676199336545361956  2022-08-28
#
# [306356 rows x 2 columns]

# %%
df_reviews_bordeaux=df_reviews_bordeaux.rename(columns={"listing_id":"id"})

# %%
df_reviews_bordeaux
# Out:
#                         id        date
# 0                   218103  2011-11-11
# 1                   218103  2012-04-12
# 2                   218103  2012-04-12
# 3                   218103  2012-04-14
# 4                   218103  2012-05-02
# ...                    ...         ...
# 306351  676160559071430643  2022-08-21
# 306352  676172890468973421  2022-08-09
# 306353  676172890468973421  2022-08-14
# 306354  676199336545361956  2022-08-14
# 306355  676199336545361956  2022-08-28
#
# [306356 rows x 2 columns]

# %%
df_neigh_bordeaux=pd.read_csv('neighbourhoods_bordeaux.csv')
df_neigh_bordeaux
# Out:
#    neighbourhood_group            neighbourhood
# 0                  NaN    Borgo Panigale - Reno
# 1                  NaN                   Navile
# 2                  NaN        Porto - Saragozza
# 3                  NaN  San Donato - San Vitale
# 4                  NaN            Santo Stefano
# 5                  NaN                   Savena

# %%
df_bordeaux.bathrooms.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10880   NaN
# 10881   NaN
# 10882   NaN
# 10883   NaN
# 10884   NaN
# Name: bathrooms, Length: 10885, dtype: float64>

# %%
df_merge=pd.merge(df_bordeaux,df_reviews_bordeaux,how="inner",on="id")

# %%
df_merge
# Out:
#                         id                                      listing_url  \
# 0                   218103              https://www.airbnb.com/rooms/218103
# 1                   218103              https://www.airbnb.com/rooms/218103
# 2                   218103              https://www.airbnb.com/rooms/218103
# 3                   218103              https://www.airbnb.com/rooms/218103
# 4                   218103              https://www.airbnb.com/rooms/218103
# ...                    ...                                              ...
# 306351  676160559071430643  https://www.airbnb.com/rooms/676160559071430643
# 306352  676172890468973421  https://www.airbnb.com/rooms/676172890468973421
# 306353  676172890468973421  https://www.airbnb.com/rooms/676172890468973421
# 306354  676199336545361956  https://www.airbnb.com/rooms/676199336545361956
# 306355  676199336545361956  https://www.airbnb.com/rooms/676199336545361956
#
#              scrape_id last_scraped       source  \
# 0       20220912200234   2022-09-13  city scrape
# 1       20220912200234   2022-09-13  city scrape
# 2       20220912200234   2022-09-13  city scrape
# 3       20220912200234   2022-09-13  city scrape
# 4       20220912200234   2022-09-13  city scrape
# ...                ...          ...          ...
# 306351  20220912200234   2022-09-12  city scrape
# 306352  20220912200234   2022-09-12  city scrape
# 306353  20220912200234   2022-09-12  city scrape
# 306354  20220912200234   2022-09-12  city scrape
# 306355  20220912200234   2022-09-12  city scrape
#
#                                                      name  \
# 0                      B&B Apart.Suite  / tropical garden
# 1                      B&B Apart.Suite  / tropical garden
# 2                      B&B Apart.Suite  / tropical garden
# 3                      B&B Apart.Suite  / tropical garden
# 4                      B&B Apart.Suite  / tropical garden
# ...                                                   ...
# 306351                    Appartement 2 chambres Bordeaux
# 306352  Magnifique Hôtel avec Patio - Chambre proche Tram
# 306353  Magnifique Hôtel avec Patio - Chambre proche Tram
# 306354  Magnifique Hôtel avec Patio - Chambre proche Tram
# 306355  Magnifique Hôtel avec Patio - Chambre proche Tram
#
#                                               description  \
# 0       <b>The space</b><br />The Bambooyard  : "Le cl...
# 1       <b>The space</b><br />The Bambooyard  : "Le cl...
# 2       <b>The space</b><br />The Bambooyard  : "Le cl...
# 3       <b>The space</b><br />The Bambooyard  : "Le cl...
# 4       <b>The space</b><br />The Bambooyard  : "Le cl...
# ...                                                   ...
# 306351  Ce logement paisible offre un séjour détente p...
# 306352  During your stay, your comfort is our priority...
# 306353  During your stay, your comfort is our priority...
# 306354  During your stay, your comfort is our priority...
# 306355  During your stay, your comfort is our priority...
#
#        neighborhood_overview  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 306351                   NaN
# 306352                   NaN
# 306353                   NaN
# 306354                   NaN
# 306355                   NaN
#
#                                               picture_url    host_id  ...  \
# 0       https://a0.muscache.com/pictures/9ba23c8f-4780...    1127981  ...
# 1       https://a0.muscache.com/pictures/9ba23c8f-4780...    1127981  ...
# 2       https://a0.muscache.com/pictures/9ba23c8f-4780...    1127981  ...
# 3       https://a0.muscache.com/pictures/9ba23c8f-4780...    1127981  ...
# 4       https://a0.muscache.com/pictures/9ba23c8f-4780...    1127981  ...
# ...                                                   ...        ...  ...
# 306351  https://a0.muscache.com/pictures/miso/Hosting-...   38174909  ...
# 306352  https://a0.muscache.com/pictures/miso/Hosting-...  470784867  ...
# 306353  https://a0.muscache.com/pictures/miso/Hosting-...  470784867  ...
# 306354  https://a0.muscache.com/pictures/miso/Hosting-...  470784867  ...
# 306355  https://a0.muscache.com/pictures/miso/Hosting-...  470784867  ...
#
#        review_scores_location review_scores_value        license  \
# 0                        4.57                4.54            NaN
# 1                        4.57                4.54            NaN
# 2                        4.57                4.54            NaN
# 3                        4.57                4.54            NaN
# 4                        4.57                4.54            NaN
# ...                       ...                 ...            ...
# 306351                   4.00                3.00  33063008259FB
# 306352                   5.00                4.50            NaN
# 306353                   5.00                4.50            NaN
# 306354                   5.00                5.00            NaN
# 306355                   5.00                5.00            NaN
#
#        instant_bookable calculated_host_listings_count  \
# 0                     f                              4
# 1                     f                              4
# 2                     f                              4
# 3                     f                              4
# 4                     f                              4
# ...                 ...                            ...
# 306351                t                              1
# 306352                t                              8
# 306353                t                              8
# 306354                t                              8
# 306355                t                              8
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                4
# 1                                                4
# 2                                                4
# 3                                                4
# 4                                                4
# ...                                            ...
# 306351                                           1
# 306352                                           0
# 306353                                           0
# 306354                                           0
# 306355                                           0
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 306351                                            0
# 306352                                            8
# 306353                                            8
# 306354                                            8
# 306355                                            8
#
#        calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                                0              0.44
# 1                                                0              0.44
# 2                                                0              0.44
# 3                                                0              0.44
# 4                                                0              0.44
# ...                                            ...               ...
# 306351                                           0              1.00
# 306352                                           0              1.71
# 306353                                           0              1.71
# 306354                                           0              2.00
# 306355                                           0              2.00
#
#               date
# 0       2011-11-11
# 1       2012-04-12
# 2       2012-04-12
# 3       2012-04-14
# 4       2012-05-02
# ...            ...
# 306351  2022-08-21
# 306352  2022-08-09
# 306353  2022-08-14
# 306354  2022-08-14
# 306355  2022-08-28
#
# [306356 rows x 76 columns]

# %%
df_faux_coment=df_bordeaux[['id','host_name']].groupby(['id','host_name']).count()
